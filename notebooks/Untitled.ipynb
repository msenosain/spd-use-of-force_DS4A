# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import numpy as np
import base64

# %%
df = pd.read_excel('../data/raw/Crisis_reports 2015-Present.xlsx')
# ../data_folder/data.csv

# %%
df['Disposition'] = df['Disposition'].str.upper().str.replace (" / ", "/", regex = True)
df['Exhibiting Behavior (group)'] = df['Exhibiting Behavior (group)'].str.upper().str.replace ("BEHAVIOR – ", "", regex = True)
df['Exhibiting Behavior (group)'] = df['Exhibiting Behavior (group)'].str.replace ("BEHAVIOR - ", "", regex = True)
df['Exhibiting Behavior (group)'] = df['Exhibiting Behavior (group)'].str.replace (" / ", "/", regex = True)
df['Exhibiting Behavior (group)'] = df['Exhibiting Behavior (group)'].str.replace ("\xa0", "", regex = True)
df['Offense/Incident Ind'] = df['Offense/Incident Ind'].str.upper()
df['Subject Gender'] = df['Subject Gender'].str.upper()
df['Subject Race'] = df['Subject Race'].str.upper()
df['Techniques Used'] = df['Techniques Used'].str.upper()
df['UoF Indicator'] = df['UoF Indicator'].str.replace ("N", "NO", regex = True)
df['UoF Indicator'] = df['UoF Indicator'].str.replace ("Y", "YES", regex = True)
df["Weapons Involved"] = df["Weapons Involved"].str.upper()
df['Weapons Involved'] = df['Weapons Involved'].str.replace("HANDGUN", "FIREARM", regex = True)
df['Weapons Involved'] = df['Weapons Involved'].str.replace ("RIFLE", "FIREARM", regex = True)
df['Weapons Involved'] = df['Weapons Involved'].str.replace ("SHOTGUN", "FIREARM", regex = True)
df['Weapons Involved'] = df['Weapons Involved'].str.replace ("OTHER FIREARM", "FIREARM", regex = True)

df = df.rename(columns = {'Exhibiting Behavior (group)': 'Behavior',
                          'Reported Date (Date)': 'Date',
                          'Offense/Incident Ind': 'OffenseIncident',
                          'Subject Age': 'Age',
                          'Subject Gender': 'Gender',
                          'Subject Race': 'Race',
                          'Techniques Used': 'Techniques',
                          'UoF Indicator': 'UoF',
                          'Weapons Involved': 'Weapons'})

df['Date'] = pd.to_datetime(df['Date'])

df['Behavior'] = df['Behavior'].str.replace ("BELLIGERENT/UNCOOPERATIVE", 'BELLIGERENT', regex = True)
df['Behavior'] = df['Behavior'].str.replace ('BELLIGERENT',"BELLIGERENT/UNCOOPERATIVE", regex = True)
df['Disposition'] = df['Disposition'].replace ("MCT (MOBILE CRISIS TEAM)", "MOBILE CRISIS TEAM" )
df['Disposition'] = df['Disposition'].replace ("RESOURCES DECLINED", "RESOURCES OFFERED/DECLINED" )
df['Disposition'] = df['Disposition'].replace ("DMHP REFERRAL", "DMHP/REFERRAL (DCR)" )
df['Disposition'] = df['Disposition'].replace ("CRISIS CLINIC (CRISIS CONNECTIONS)", "CRISIS CLINIC" )
df['Disposition'] = df['Disposition'].replace ("SHELTER", "SHELTER / SHELTER TRANSPORT" )
df['Disposition'] = df['Disposition'].replace ("SHELTER TRANSPORT", "SHELTER / SHELTER TRANSPORT" )
df['Disposition'] = df['Disposition'].replace ("CASE MANAGER/MH AGENCY NOTIFIED", "MENTAL HEALTH AGENCY OR CASE MANAGER NOTIFIED" )
df['Disposition'] = df['Disposition'].replace ("DRUG/ALCOHOL TREATMENT REFERRAL", "SOCIAL SERVICE/ALCOHOL AND DRUG/TREATMENT REFERRAL" )
df['Disposition'] = df['Disposition'].replace ("ARRESTED (REQUIRES ARREST REPORT)", "ARRESTED" )
OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 78643          OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 78645          OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 78647          OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 78649          OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 78651          OUT OF TOUCH WITH REALITY         OFFENSE   41   MALE  WHITE
# 83837  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
# 83839  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
# 83841  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
# 83843  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
# 83845  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
# 83847  PHYSICALLY THREATENING/AGGRESSIVE         OFFENSE   41   MALE  WHITE
#
#           Techniques  UoF                               Weapons       Date
# 31998         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 32000         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 32002    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 32004    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 32006  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 32008  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 35525         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 35527         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 35529    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 35531    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 35533  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 35535  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 51830         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 51832         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 51834    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 51836    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 51838  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 51840  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 54796         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 54798         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 54800    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 54802    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 54804  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 54806  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 71968         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 71970         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 71972    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 71974    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 71976  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 71978  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 78641         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 78643         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 78645    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 78647    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 78649  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 78651  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24
# 83837         GURNEY  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 83839         GURNEY  YES                        TASER/STUN GUN 2020-09-24
# 83841    HANDCUFFING  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 83843    HANDCUFFING  YES                        TASER/STUN GUN 2020-09-24
# 83845  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 83847  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24

# %%
#offense
cad_1['Techniques'].value_counts()
# Out:
# VERBALIZATION    14
# GURNEY           14
# HANDCUFFING      14
# Name: Techniques, dtype: int64

# %%
#Behavior, Techniques, OffenseIncident, WEAPONS all change

# %%
#offense
cad_1['Behavior'].value_counts()
# Out:
# DISORDERLY/DISRUPTIVE                6
# BELLIGERENT/UNCOOPERATIVE            6
# BIZARRE/UNUSUAL                      6
# PHYSICALLY THREATENING/AGGRESSIVE    6
# OUT OF TOUCH WITH REALITY            6
# NEGLECT/SELF CARE                    6
# DISORGANIZED SPEECH/COMMUNICATION    6
# Name: Behavior, dtype: int64

# %%
cad_2 = df[df['CAD Event ID']==2020000275830] #84 rows 
cad_2 = cad_2[cad_2['OffenseIncident'] == 'INCIDENT']
cad_2 = cad_2[(cad_2['Techniques'] == 'VERBALIZATION')& (cad_2['Behavior'] == 'DISORDERLY/DISRUPTIVE')]

cad_2
# Out:
#        Behavioral Crisis Num   CAD Event ID Disposition  \
# 51837            15683572604  2020000275830    ARRESTED
# 51839            15683572604  2020000275830    ARRESTED
#
#                     Behavior OffenseIncident  Age Gender   Race  \
# 51837  DISORDERLY/DISRUPTIVE        INCIDENT   41   MALE  WHITE
# 51839  DISORDERLY/DISRUPTIVE        INCIDENT   41   MALE  WHITE
#
#           Techniques  UoF                               Weapons       Date
# 51837  VERBALIZATION  YES  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2020-09-24
# 51839  VERBALIZATION  YES                        TASER/STUN GUN 2020-09-24

# %%
#incident
cad_2['Techniques'].value_counts()
# Out:
# VERBALIZATION    14
# GURNEY           14
# HANDCUFFING      14
# Name: Techniques, dtype: int64

# %%
#incident
cad_2['Behavior'].value_counts()
# Out:
# DISORDERLY/DISRUPTIVE                6
# BELLIGERENT/UNCOOPERATIVE            6
# BIZARRE/UNUSUAL                      6
# PHYSICALLY THREATENING/AGGRESSIVE    6
# OUT OF TOUCH WITH REALITY            6
# NEGLECT/SELF CARE                    6
# DISORGANIZED SPEECH/COMMUNICATION    6
# Name: Behavior, dtype: int64

# %%
cad = df[df['CAD Event ID']==2020000275830] #84 rows 
cad = cad.groupby(['Behavioral Crisis Num', 'CAD Event ID', 'Disposition', 'Race', 'Gender', 'Age', 'UoF']).size()
cad
# Out:
# Behavioral Crisis Num  CAD Event ID   Disposition  Race   Gender  Age  UoF
# 15683572604            2020000275830  ARRESTED     WHITE  MALE    41   YES    84
# dtype: int64

# %%
cad_other = df[df['CAD Event ID']== 2021000035300] 
cad_other
# Out:
#        Behavioral Crisis Num   CAD Event ID             Disposition  \
# 33139            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 33140            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 33141            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 33142            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 33143            20472474255  2021000035300  EMERGENT DETENTION/ITA
# ...                      ...            ...                     ...
# 99619            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 99620            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 99621            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 99622            20472474255  2021000035300  EMERGENT DETENTION/ITA
# 99623            20472474255  2021000035300  EMERGENT DETENTION/ITA
#
#                               Behavior OffenseIncident  Age  Gender   Race  \
# 33139        BELLIGERENT/UNCOOPERATIVE        INCIDENT   26  FEMALE  WHITE
# 33140        BELLIGERENT/UNCOOPERATIVE         OFFENSE   26  FEMALE  WHITE
# 33141        BELLIGERENT/UNCOOPERATIVE        INCIDENT   26  FEMALE  WHITE
# 33142        BELLIGERENT/UNCOOPERATIVE         OFFENSE   26  FEMALE  WHITE
# 33143        BELLIGERENT/UNCOOPERATIVE        INCIDENT   26  FEMALE  WHITE
# ...                                ...             ...  ...     ...    ...
# 99619  VERBALLY THREATENING/AGGRESSIVE         OFFENSE   26  FEMALE  WHITE
# 99620  VERBALLY THREATENING/AGGRESSIVE        INCIDENT   26  FEMALE  WHITE
# 99621  VERBALLY THREATENING/AGGRESSIVE         OFFENSE   26  FEMALE  WHITE
# 99622  VERBALLY THREATENING/AGGRESSIVE        INCIDENT   26  FEMALE  WHITE
# 99623  VERBALLY THREATENING/AGGRESSIVE         OFFENSE   26  FEMALE  WHITE
#
#           Techniques UoF              Weapons       Date
# 33139         GURNEY  NO  NONE/NOT APPLICABLE 2021-02-11
# 33140         GURNEY  NO  NONE/NOT APPLICABLE 2021-02-11
# 33141    HANDCUFFING  NO  NONE/NOT APPLICABLE 2021-02-11
# 33142    HANDCUFFING  NO  NONE/NOT APPLICABLE 2021-02-11
# 33143  VERBALIZATION  NO  NONE/NOT APPLICABLE 2021-02-11
# ...              ...  ..                  ...        ...
# 99619         GURNEY  NO  NONE/NOT APPLICABLE 2021-02-11
# 99620    HANDCUFFING  NO  NONE/NOT APPLICABLE 2021-02-11
# 99621    HANDCUFFING  NO  NONE/NOT APPLICABLE 2021-02-11
# 99622  VERBALIZATION  NO  NONE/NOT APPLICABLE 2021-02-11
# 99623  VERBALIZATION  NO  NONE/NOT APPLICABLE 2021-02-11
#
# [66 rows x 12 columns]

# %%
cad_other = cad_other.groupby(['Behavioral Crisis Num', 'CAD Event ID', 'Disposition', 'Race', 'Gender', 'Age', 'UoF']).size()
cad_other
# Out:
# Behavioral Crisis Num  CAD Event ID   Disposition             Race   Gender  Age  UoF
# 20472474255            2021000035300  EMERGENT DETENTION/ITA  WHITE  FEMALE  26   NO     66
# dtype: int64

# %%
cad_other_2 = df[df['CAD Event ID']== 2020000183257] 
cad_other_2 = cad_other_2.groupby(['Behavioral Crisis Num', 'CAD Event ID', 'Disposition', 'Race', 'Gender', 'Age', 'UoF']).size()
cad_other
# Out:
# Behavioral Crisis Num  CAD Event ID   Disposition             Race   Gender  Age  UoF
# 20472474255            2021000035300  EMERGENT DETENTION/ITA  WHITE  FEMALE  26   NO     66
# dtype: int64

# %%
cad_other_3 = df[df['CAD Event ID']== 2020000287444] 
cad_other_3 = cad_other_3.groupby(['Behavioral Crisis Num', 'CAD Event ID', 'Disposition', 'Race', 'Gender', 'Age', 'UoF']).size()
cad_other
# Out:
# Behavioral Crisis Num  CAD Event ID   Disposition             Race   Gender  Age  UoF
# 20472474255            2021000035300  EMERGENT DETENTION/ITA  WHITE  FEMALE  26   NO     66
# dtype: int64

# %%
total_cad = df.groupby(['Behavioral Crisis Num', 'CAD Event ID', 'Disposition', 'Race', 'Gender', 'Age', 'UoF']).size()
total_cad = pd.DataFrame(data = total_cad)

# %%
df
# Out:
#         Behavioral Crisis Num   CAD Event ID  \
# 0                       43653  2015000159907
# 1                       43719  2015000160408
# 2                       43845  2015000160465
# 3                       43992  2015000159631
# 4                       44102             -1
# ...                       ...            ...
# 100027            25401359124  2021000138785
# 100028            25402273014  2021000139195
# 100029            25403315882  2021000139353
# 100030            25411056808  2021000140798
# 100031            25411361318  2021000141014
#
#                                            Disposition  \
# 0       NO ACTION POSSIBLE/NECESSARY/UNABLE TO CONTACT
# 1       NO ACTION POSSIBLE/NECESSARY/UNABLE TO CONTACT
# 2                           RESOURCES OFFERED/DECLINED
# 3                   GERIATRIC REGIONAL ASSESSMENT TEAM
# 4                                  VOLUNTARY COMMITTAL
# ...                                                ...
# 100027                                        ARRESTED
# 100028                      RESOURCES OFFERED/DECLINED
# 100029                                        ARRESTED
# 100030                      RESOURCES OFFERED/DECLINED
# 100031                      RESOURCES OFFERED/DECLINED
#
#                                Behavior OffenseIncident  Age  Gender  \
# 0                                     -               -   -1       -
# 1                                     -               -   -1       -
# 2                                     -               -   -1       -
# 3                                     -               -   -1       -
# 4                                     -               -   -1       -
# ...                                 ...             ...  ...     ...
# 100027  VERBALLY THREATENING/AGGRESSIVE         OFFENSE   34    MALE
# 100028  VERBALLY THREATENING/AGGRESSIVE        INCIDENT   40  FEMALE
# 100029  VERBALLY THREATENING/AGGRESSIVE         OFFENSE   22  FEMALE
# 100030  VERBALLY THREATENING/AGGRESSIVE        INCIDENT   22  FEMALE
# 100031  VERBALLY THREATENING/AGGRESSIVE               -   22  FEMALE
#
#                              Race     Techniques UoF  \
# 0                               -              -  NO
# 1                               -              -  NO
# 2                               -              -  NO
# 3                               -              -  NO
# 4                               -              -  NO
# ...                           ...            ...  ..
# 100027  BLACK OR AFRICAN AMERICAN  VERBALIZATION  NO
# 100028                      WHITE  VERBALIZATION  NO
# 100029                      WHITE  VERBALIZATION  NO
# 100030                    UNKNOWN  VERBALIZATION  NO
# 100031                    UNKNOWN  VERBALIZATION  NO
#
#                                      Weapons       Date
# 0                                          - 2015-05-15
# 1                                          - 2015-05-16
# 2                                          - 2015-05-16
# 3                                          - 2015-05-15
# 4                                          - 2015-05-16
# ...                                      ...        ...
# 100027                   NONE/NOT APPLICABLE 2021-06-05
# 100028                     MACE/PEPPER SPRAY 2021-06-05
# 100029  PERSONAL WEAPONS (HANDS, FEET, ETC.) 2021-06-06
# 100030                   NONE/NOT APPLICABLE 2021-06-07
# 100031                   NONE/NOT APPLICABLE 2021-06-07
#
# [100032 rows x 12 columns]

# %%
total_cad = total_cad[total_cad['UoF']== 'NO']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-cbad175fddc5> in <module>
# ----> 1 total_cad = total_cad[total_cad['UoF']== 'NO']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'UoF'

# %%
total_cad.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
#airbnb
